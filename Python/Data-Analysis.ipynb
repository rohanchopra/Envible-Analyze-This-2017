# %%
import missingno as mn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = pd.read_csv('./Dataset/Training_Dataset.csv')

# %%
data.drop('mvar1',inplace=True,axis=1)
data.drop('cm_key',inplace=True,axis=1)

# %% [markdown]
# ## Missing data visualization

# %%
data_nan = data.replace(0, np.nan)

# %%
mn.dendrogram(data_nan)
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
mn.heatmap(data_nan)
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
data_nan.drop('mvar16',inplace=True,axis=1)
data_nan.drop('mvar17',inplace=True,axis=1)
data_nan.drop('mvar18',inplace=True,axis=1)
data_nan.drop('mvar19',inplace=True,axis=1)
data_nan.drop('mvar20',inplace=True,axis=1)
data_nan.drop('mvar21',inplace=True,axis=1)
data_nan.drop('mvar22',inplace=True,axis=1)
data_nan.drop('mvar23',inplace=True,axis=1)
data_nan.drop('mvar24',inplace=True,axis=1)
data_nan.drop('mvar25',inplace=True,axis=1)
data_nan.drop('mvar26',inplace=True,axis=1)
data_nan.drop('mvar27',inplace=True,axis=1)
data_nan.drop('mvar28',inplace=True,axis=1)
data_nan.drop('mvar29',inplace=True,axis=1)
data_nan.drop('mvar30',inplace=True,axis=1)
data_nan.drop('mvar31',inplace=True,axis=1)
data_nan.drop('mvar32',inplace=True,axis=1)
data_nan.drop('mvar33',inplace=True,axis=1)
data_nan.drop('mvar34',inplace=True,axis=1)
data_nan.drop('mvar35',inplace=True,axis=1)
data_nan.drop('mvar36',inplace=True,axis=1)
data_nan.drop('mvar37',inplace=True,axis=1)
data_nan.drop('mvar38',inplace=True,axis=1)
data_nan.drop('mvar39',inplace=True,axis=1)
data_nan.drop('mvar40',inplace=True,axis=1)
data_nan.drop('mvar41',inplace=True,axis=1)
data_nan.drop('mvar42',inplace=True,axis=1)
data_nan.drop('mvar43',inplace=True,axis=1)
data_nan.drop('mvar44',inplace=True,axis=1)
data_nan.drop('mvar45',inplace=True,axis=1)
data_nan.drop('mvar46',inplace=True,axis=1)
data_nan.drop('mvar47',inplace=True,axis=1)
data_nan.drop('mvar48',inplace=True,axis=1)
data_nan.drop('mvar49',inplace=True,axis=1)
data_nan.drop('mvar50',inplace=True,axis=1)
data_nan.drop('mvar51',inplace=True,axis=1)

# %%
mn.matrix(data_nan)
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
mn.dendrogram(data_nan)
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
mn.heatmap(data_nan)
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
data_nan.drop('mvar4',inplace=True,axis=1)
data_nan.drop('mvar13',inplace=True,axis=1)
data_nan.drop('mvar15',inplace=True,axis=1)
data_nan.drop('mvar14',inplace=True,axis=1)

# %%
mn.matrix(data_nan)
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
mn.dendrogram(data_nan)
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
mn.heatmap(data_nan)

# %% [markdown]
# ### Target generation

# %%
data.head()
# Out:
#    mvar2   mvar3  mvar4  mvar5  mvar6   mvar7   mvar8    mvar9  mvar10  \
# 0      0  106920      4     18    970  0.7969  0.1831   337236       1
# 1      2       0      4     19   1030  0.0678  0.0000  2918974       1
# 2      2  399168      4     35    327  0.7551  0.2986   498656       0
# 3      0  267300      4    274   1258  0.7969  0.5297  2480074       1
# 4      0  213840      6      1      0  2.3238  0.0000  2918974       0
#
#    mvar11   ...   mvar42  mvar43  mvar44  mvar45  mvar46  mvar47  mvar48  \
# 0  6.0899   ...        0       0       0       0       0       0       1
# 1  4.2016   ...        0       0       0       0       1       0       0
# 2  3.3760   ...        0       0       0       0       0       0       1
# 3  4.1082   ...        0       1       0       0       0       0       1
# 4  0.0000   ...        0       0       0       0       1       0       0
#
#    mvar49  mvar50  mvar51
# 0       0       0       0
# 1       0       0       0
# 2       0       0       0
# 3       0       0       1
# 4       1       0       0
#
# [5 rows x 50 columns]

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(data['mvar12'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['Apparel', 'Automotive         ', 'Construction       ',
#        'Consumables        ', 'Durable goods      ', 'Entertainment      ',
#        'Finance            ', 'Household          ', 'Manufacturing      ',
#        'Mining             ', 'Misc services      ', 'Non durable goods  ',
#        'Office supplies    ', 'Personal services  ', 'Produce            ',
#        'Social services    ', 'Transport          ', 'Unknown            '], dtype=object)

# %%
data['mvar12'] = le.transform(data['mvar12'])

# %%
target_ = list()
for i in range(len(data)):
    if data['mvar49'][i] == 1:
        target_.append(3)
    elif data['mvar50'][i] == 1:
        target_.append(2)
    elif data['mvar51'][i] == 1:
        target_.append(1)
    else:
        target_.append(0)

# %%
target = list()
for i in range(len(data)):
    if data['mvar49'][i] == 1:
        target.append(1)
    elif data['mvar50'][i] == 1:
        target.append(1)
    elif data['mvar51'][i] == 1:
        target.append(1)
    else:
        target.append(0)

# %%
data['target']= target

# %%
data['multiTarget']= target_

# %%
data.drop('mvar46',inplace=True,axis=1)
data.drop('mvar47',inplace=True,axis=1)
data.drop('mvar48',inplace=True,axis=1)
data.drop('mvar49',inplace=True,axis=1)
data.drop('mvar50',inplace=True,axis=1)
data.drop('mvar51',inplace=True,axis=1)

# %%
data.lt(0).sum()
# Out:
# mvar2           0
# mvar3           0
# mvar4           0
# mvar5           0
# mvar6           0
# mvar7           0
# mvar8           0
# mvar9           0
# mvar10          0
# mvar11          0
# mvar12          0
# mvar13          0
# mvar14          0
# mvar15          0
# mvar16          0
# mvar17          0
# mvar18          0
# mvar19          0
# mvar20          0
# mvar21          0
# mvar22          0
# mvar23          0
# mvar24          0
# mvar25          0
# mvar26          0
# mvar27          0
# mvar28          0
# mvar29          0
# mvar30          0
# mvar31          0
# mvar32         33
# mvar33         20
# mvar34         14
# mvar35         20
# mvar36          0
# mvar37          0
# mvar38          0
# mvar39          0
# mvar40          0
# mvar41          0
# mvar42          0
# mvar43          0
# mvar44          0
# mvar45          0
# target          0
# multiTarget     0
# dtype: int64

# %% [markdown]
# Retail spending has negative values
# - Dropping retail spending

# %%
dataPos = data.copy()
dataPos.drop('mvar32',inplace=True,axis=1)
dataPos.drop('mvar33',inplace=True,axis=1)
dataPos.drop('mvar34',inplace=True,axis=1)
dataPos.drop('mvar35',inplace=True,axis=1)

# %% [markdown]
# Summarize Score

# %%
plt.scatter(data['mvar38'],data['mvar37'])
plt.show()

# %%
retailSpend = data['mvar32']+data['mvar33']+data['mvar34']+data['mvar35']

# %%
retailSpend.lt(0).sum()
# Out:
# 2

# %%
retailSpend.eq(0).sum()
# Out:
# 22689

# %%
dataYear = data.copy()

# %% [markdown]
# - Score after summing quarterly spends - 30100
# - Score after summing quarterly spends and removing mvar3- 29800

# %%
dataYear['ElectronicsSpend'] = data['mvar16']+data['mvar17']+data['mvar18']+data['mvar19']
dataYear['TravelSpend'] = data['mvar20']+data['mvar21']+data['mvar22']+data['mvar23']
dataYear['HouseholdSpend'] = data['mvar27']+data['mvar26']+data['mvar25']+data['mvar24']
dataYear['CarSpend'] = data['mvar28']+data['mvar29']+data['mvar30']+data['mvar31']
dataYear['RetailSpend'] = data['mvar32']+data['mvar33']+data['mvar34']+data['mvar35']
dataYear['TotalSpend'] = data['mvar36']+data['mvar37']+data['mvar38']+data['mvar39']

# %%
dataYear.drop('mvar16',inplace=True,axis=1)
dataYear.drop('mvar17',inplace=True,axis=1)
dataYear.drop('mvar18',inplace=True,axis=1)
dataYear.drop('mvar19',inplace=True,axis=1)
dataYear.drop('mvar20',inplace=True,axis=1)
dataYear.drop('mvar21',inplace=True,axis=1)
dataYear.drop('mvar22',inplace=True,axis=1)
dataYear.drop('mvar23',inplace=True,axis=1)
dataYear.drop('mvar24',inplace=True,axis=1)
dataYear.drop('mvar25',inplace=True,axis=1)
dataYear.drop('mvar26',inplace=True,axis=1)
dataYear.drop('mvar27',inplace=True,axis=1)
dataYear.drop('mvar28',inplace=True,axis=1)
dataYear.drop('mvar29',inplace=True,axis=1)
dataYear.drop('mvar30',inplace=True,axis=1)
dataYear.drop('mvar31',inplace=True,axis=1)
dataYear.drop('mvar32',inplace=True,axis=1)
dataYear.drop('mvar33',inplace=True,axis=1)
dataYear.drop('mvar34',inplace=True,axis=1)
dataYear.drop('mvar35',inplace=True,axis=1)
dataYear.drop('mvar36',inplace=True,axis=1)
dataYear.drop('mvar37',inplace=True,axis=1)
dataYear.drop('mvar38',inplace=True,axis=1)
dataYear.drop('mvar39',inplace=True,axis=1)

# %%
dataYear.head()
# Out:
#    mvar2   mvar3  mvar4  mvar5  mvar6   mvar7   mvar8    mvar9  mvar10  \
# 0      0  106920      4     18    970  0.7969  0.1831   337236       1
# 1      2       0      4     19   1030  0.0678  0.0000  2918974       1
# 2      2  399168      4     35    327  0.7551  0.2986   498656       0
# 3      0  267300      4    274   1258  0.7969  0.5297  2480074       1
# 4      0  213840      6      1      0  2.3238  0.0000  2918974       0
#
#    mvar11     ...      mvar43  mvar44  mvar45  target  ElectronicsSpend  \
# 0  6.0899     ...           0       0       0       0              0.00
# 1  4.2016     ...           0       0       0       0            121.28
# 2  3.3760     ...           0       0       0       0           1608.36
# 3  4.1082     ...           1       0       0       1           4219.22
# 4  0.0000     ...           0       0       0       1              0.00
#
#    TravelSpend  HouseholdSpend  CarSpend  RetailSpend  TotalSpend
# 0      2228.77         1006.52      0.00         0.00   642634.00
# 1        65.89            0.00      0.00         0.00    44186.44
# 2       634.27          840.68      0.00         0.00   208561.15
# 3     15572.73          599.48   1307.61    115194.92   124592.82
# 4    198986.83         1235.00      0.00         0.00   382959.35
#
# [5 rows x 27 columns]

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA as sklearnPCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.datasets.samples_generator import make_blobs

from pandas.tools.plotting import parallel_coordinates

# %%
X = dataYear.copy()
X.drop('target',inplace=True,axis=1)
y = dataYear['target']

# %%
y_ = target_

# %%
X_norm = (X - X.min())/(X.max() - X.min())

# %%
pca = sklearnPCA(n_components=2) #2-dimensional PCA
transformed = pd.DataFrame(pca.fit_transform(X_norm))

# %%
plt.scatter(transformed[y==0][0], transformed[y==0][1], label='Class 0', c='red')
plt.scatter(transformed[y==1][0], transformed[y==1][1], label='Class 1', c='blue')

plt.legend()
plt.show()

# %% [markdown]
# ### LDA

# %%
lda = LDA(n_components=2) #2-dimensional LDA
lda_transformed = pd.DataFrame(lda.fit_transform(X_norm, y_))

# %%
plt.scatter(lda_transformed[y==0][0], lda_transformed[y==0][1], label='Class 0', c='red')
plt.scatter(lda_transformed[y==1][0], lda_transformed[y==1][1], label='Class 1', c='blue')
plt.legend()
plt.show()

# %% [markdown]
# ### Box plot

# %%
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
dataYear.plot(kind='box', subplots=True, layout=(6,6), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# ### Scatter Matrix

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(dataYear)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-56f89e0a743e> in <module>()
# ----> 1 scatter_matrix(dataYear)
#       2 plt.show()
#
# ~/.local/lib/python3.5/site-packages/pandas/plotting/_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      58     naxes = n * n
#      59     fig, axes = _subplots(naxes=naxes, figsize=figsize, ax=ax,
# ---> 60                           squeeze=False)
#      61
#      62     # no gaps between subplots
#
# ~/.local/lib/python3.5/site-packages/pandas/plotting/_tools.py in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     254             kwds['sharex'] = None
#     255             kwds['sharey'] = None
# --> 256         ax = fig.add_subplot(nrows, ncols, i + 1, **kwds)
#     257         axarr[i] = ax
#     258
#
# ~/.local/lib/python3.5/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1019                     self._axstack.remove(ax)
#    1020
# -> 1021             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1022
#    1023         self._axstack.add(key, a)
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     527
#     528         # this call may differ for non-sep axes, e.g., polar
# --> 529         self._init_axis()
#     530         if axisbg is not None and facecolor is not None:
#     531             raise TypeError('Both axisbg and facecolor are not None. '
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in _init_axis(self)
#     621         "move this out of __init__ because non-separable axes don't use it"
#     622         self.xaxis = maxis.XAxis(self)
# --> 623         self.spines['bottom'].register_axis(self.xaxis)
#     624         self.spines['top'].register_axis(self.xaxis)
#     625         self.yaxis = maxis.YAxis(self)
#
# ~/.local/lib/python3.5/site-packages/matplotlib/spines.py in register_axis(self, axis)
#     161         self.axis = axis
#     162         if self.axis is not None:
# --> 163             self.axis.cla()
#     164         self.stale = True
#     165
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axis.py in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axis.py in reset_ticks(self)
#     773
#     774         self.majorTicks.extend([self._get_tick(major=True)])
# --> 775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#     777         self._lastNumMinorTicks = 1
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     432                           markersize=self._size,
#     433                           markeredgewidth=self._width,
# --> 434                           zorder=self._zorder)
#     435
#     436         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# ~/.local/lib/python3.5/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         self._color = None
#     403         self.set_color(color)
# --> 404         self._marker = MarkerStyle()
#     405         self.set_marker(marker)
#     406
#
# ~/.local/lib/python3.5/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     184         # _recache() in set_marker.
#     185         self._fillstyle = fillstyle
# --> 186         self.set_marker(marker)
#     187         self.set_fillstyle(fillstyle)
#     188
#
# KeyboardInterrupt:

# %% [markdown]
# ### PCA - 4 class

# %%
X = dataYear.copy()
X.drop('target',inplace=True,axis=1)
y = dataYear['target']

# %%
X.drop('RetailSpend',inplace=True,axis=1)
X.drop('mvar40',inplace=True,axis=1)
X.drop('mvar41',inplace=True,axis=1)
X.drop('mvar42',inplace=True,axis=1)

# %%
X_norm = (X - X.min())/(X.max() - X.min())

# %%
pca = sklearnPCA(n_components=2) #2-dimensional PCA
transformed = pd.DataFrame(pca.fit_transform(X_norm))

# %%
plt.scatter(transformed[y==0][0], transformed[y==0][1], label='Class 0', c='red')
plt.scatter(transformed[y==1][0], transformed[y==1][1], label='Class 1', c='blue')
plt.scatter(transformed[y==2][0], transformed[y==2][1], label='Class 2', c='green')
plt.scatter(transformed[y==3][0], transformed[y==3][1], label='Class 3', c='yellow')

plt.legend()
plt.show()

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# Create a feature using mvar40 - mvar45 where compare mvar40 and mvar43 ...

# %% [markdown]
# ### Check salaried account hypothesis

# %%
X.head()
# Out:
#    mvar2   mvar3  mvar4  mvar5  mvar6   mvar7   mvar8    mvar9  mvar10  \
# 0      0  106920      4     18    970  0.7969  0.1831   337236       1
# 1      2       0      4     19   1030  0.0678  0.0000  2918974       1
# 2      2  399168      4     35    327  0.7551  0.2986   498656       0
# 3      0  267300      4    274   1258  0.7969  0.5297  2480074       1
# 4      0  213840      6      1      0  2.3238  0.0000  2918974       0
#
#    mvar11     ...      mvar42  mvar43  mvar44  mvar45  ElectronicsSpend  \
# 0  6.0899     ...           0       0       0       0              0.00
# 1  4.2016     ...           0       0       0       0            121.28
# 2  3.3760     ...           0       0       0       0           1608.36
# 3  4.1082     ...           0       1       0       0           4219.22
# 4  0.0000     ...           0       0       0       0              0.00
#
#    TravelSpend  HouseholdSpend  CarSpend  RetailSpend  TotalSpend
# 0      2228.77         1006.52      0.00         0.00   642634.00
# 1        65.89            0.00      0.00         0.00    44186.44
# 2       634.27          840.68      0.00         0.00   208561.15
# 3     15572.73          599.48   1307.61    115194.92   124592.82
# 4    198986.83         1235.00      0.00         0.00   382959.35
#
# [5 rows x 26 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    1
# Name: target, dtype: int64

# %%
plt.scatter(X['mvar3']>0, y)
plt.show()

# %%
plt.scatter(X['mvar3'], y)
plt.show()

# %%
X['mvar3'].describe()
# Out:
# count     40000.000000
# mean      45507.619525
# std       86013.548027
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%       57736.000000
# max      434629.000000
# Name: mvar3, dtype: float64

# %%
pd.crosstab(X.mvar3>0,y, margins=True)
# Out:
# target      0     1     2     3    All
# mvar3
# False   19086  1523  1575  2170  24354
# True    12036  1254  1079  1277  15646
# All     31122  2777  2654  3447  40000

# %%
pd.crosstab(X.mvar3>3000,y, margins=True)
# Out:
# target      0     1    All
# mvar3
# False   19255  5328  24583
# True    11867  3550  15417
# All     31122  8878  40000

# %%
pd.crosstab(X.mvar3>0,y, margins=True)
# Out:
# target      0     1    All
# mvar3
# False   19086  5268  24354
# True    12036  3610  15646
# All     31122  8878  40000

# %% [markdown]
# ### Frequency matrices

# %%
pd.crosstab(X.mvar2,y, margins=True)
# Out:
# target      0     1    All
# mvar2
# 0       16028  4780  20808
# 1        7378  1570   8948
# 2        2848   701   3549
# 3        1443   465   1908
# 4        2115   707   2822
# 5         909   386   1295
# 6         162    88    250
# 7          85    55    140
# 8          45    38     83
# 9          33    28     61
# 10         18    18     36
# 11         58    42    100
# All     31122  8878  40000

# %%
pd.crosstab(X.mvar2,data['multiTarget'], margins=True)
# Out:
# multiTarget      0     1     2     3    All
# mvar2
# 0            16028  2009  1459  1312  20808
# 1             7378   441   636   493   8948
# 2             2848   139   261   301   3549
# 3             1443    71   130   264   1908
# 4             2115    75   115   517   2822
# 5              909    38    46   302   1295
# 6              162     1     3    84    250
# 7               85     0     1    54    140
# 8               45     0     2    36     83
# 9               33     1     0    27     61
# 10              18     1     0    17     36
# 11              58     1     1    40    100
# All          31122  2777  2654  3447  40000

# %% [markdown]
# **Family size pretty good indicator for Supp card**

# %% [markdown]
# TODO: remove any row with negative retail spend

# %%
X.RetailSpend.describe()
# Out:
# count    4.000000e+04
# mean     1.333081e+05
# std      1.509908e+06
# min     -1.897190e+03
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      6.019716e+04
# max      1.925738e+08
# Name: RetailSpend, dtype: float64

# %%
pd.crosstab(X.RetailSpend > 1333081,y, margins=True)
# Out:
# target           0     1    All
# RetailSpend
# False        30661  8672  39333
# True           461   206    667
# All          31122  8878  40000

# %%
X.loc[(data.mvar32<0) |(data.mvar33<0) |(data.mvar34<0) |(data.mvar35<0)]
# Out:
#        mvar2   mvar3  mvar4  mvar5  mvar6   mvar7   mvar8    mvar9  mvar10  \
# 94         1       0      3     18    245  0.0101  0.2310   203463       0
# 144        0       0      5    131    981  0.0904  0.0000  2918974       1
# 770        5   58806      7      9   1289  0.0503  0.0000  2918974       1
# 1122       6   58806      9     30   2419  0.1591  0.0000  2918974       1
# 34760         0.00            0.00      0.00     13607.11    22318.93
# 35010         0.00            0.00  11736.42     21664.70    30839.47
# 35296         0.00            0.00     73.61      8374.93    15365.92
# 36230      1991.88            0.00     55.76     80017.79    91324.07
# 37501       780.44            0.00     26.94     12726.25    23780.44
# 37535         0.00            0.00      0.00     18921.64    12252.02
# 37599      3031.57            0.00    614.78      3996.99    10934.50
# 38130         0.00            0.00     79.50      1411.38    62699.83
# 38268         0.00            0.00      0.00       579.99      793.23
# 38856         0.00            0.00      0.00       419.79     3174.93
# 38951         0.00            0.00   2488.98     41318.34    23222.86
# 39557      2126.51            0.00     62.51     10568.01    43219.04
#
# [85 rows x 26 columns]

# %%
pd.crosstab(X.mvar14,data['multiTarget'], margins=True)
# Out:
# multiTarget      0     1     2     3    All
# mvar14
# 0              237     7     1    33    278
# 1            30258  2681  2442  3353  38734
# 2              364    49    64    26    503
# 3              119    22    42    13    196
# 4               64    10    22    12    108
# 5               34     4    32     3     73
# 6               27     3    32     3     65
# 7               10     1    12     3     26
# 8                5     0     4     0      9
# 9                4     0     3     1      8
# All          31122  2777  2654  3447  40000

# %%
pd.crosstab(X.mvar4,data['multiTarget'], margins=True)
# Out:
# multiTarget      0     1     2     3    All
# mvar4
# 0             2391   129   156   272   2948
# 1             5192   361   382   599   6534
# 2             5960   486   519   653   7618
# 3             5268   503   426   578   6775
# 4             6488   629   630   733   8480
# 5             1820   224   178   190   2412
# 6             1246   138   114   139   1637
# 7              842    81    81    85   1089
# 8              943   113    88    88   1232
# 9              249    25    19    39    332
# 10             207    26    19    17    269
# 11             143    14     9    10    176
# 12             373    48    33    44    498
# All          31122  2777  2654  3447  40000

# %%
pd.crosstab(X.mvar4,data['target'], margins=True)
# Out:
# target      0     1    All
# mvar4
# 0        2391   557   2948
# 1        5192  1342   6534
# 2        5960  1658   7618
# 3        5268  1507   6775
# 4        6488  1992   8480
# 5        1820   592   2412
# 6        1246   391   1637
# 7         842   247   1089
# 8         943   289   1232
# 9         249    83    332
# 10        207    62    269
# 11        143    33    176
# 12        373   125    498
# All     31122  8878  40000

# %%
pd.crosstab(X.mvar13,data['target'], margins=True)
# Out:
# target      0     1    All
# mvar13
# 0         220    69    289
# 2          83    19    102
# 3         109    21    130
# 4         157    39    196
# 5         151    50    201
# 6         590   172    762
# 7        1216   349   1565
# 8        2270   567   2837
# 9        1976   513   2489
# 10       2886   789   3675
# 11       3377   947   4324
# 12       3514  1062   4576
# 13       4075  1204   5279
# 14       3556  1087   4643
# 15       2935   860   3795
# 16       2016   549   2565
# 17       1071   301   1372
# 18        519   137    656
# 19        230    84    314
# 20         87    34    121
# 21         39    12     51
# 22         20     5     25
# 23         25     8     33
# All     31122  8878  40000

# %%
pd.crosstab(X.mvar44,data['multiTarget'], margins=True)
# Out:
# multiTarget      0     1     2     3    All
# mvar44
# 0            30671  2702  2647  3371  39391
# 1              189    27     3    24    243
# 2              230    47     4    43    324
# 3               30     1     0     9     40
# 4                2     0     0     0      2
# All          31122  2777  2654  3447  40000

# %%
sum((X.mvar42 > 0) & (X.mvar45 > 0))
# Out:
# 197
